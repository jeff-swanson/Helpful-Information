# %% [markdown]
# # Clinical NLP

# %% [markdown]
# scispaCy is an open-source software library for advanced Natural Language Processing, written in the programming languages Python and Cython. The library is published under the MIT license and currently offers statistical neural network models for processing biomedical, scientific or clinical text.

# %% [markdown]
# ## Finding the sentences in the text

# %%
import scispacy
import spacy
import en_ner_bc5cdr_md   #The model we are going to use
from spacy import displacy
from scispacy.abbreviation import AbbreviationDetector
from scispacy.linking import EntityLinker
nlp = spacy.load("en_ner_bc5cdr_md")

import pandas as pd
import re
med_transcript = pd.read_csv(r"C:\Users\swanson-jeffrey\Downloads\mtsamples.csv", index_col=0)
med_transcript.dropna(subset=['transcription'], inplace=True)

text=med_transcript_small['transcription'].iloc[10]

text=re.sub(r'[^\w\s]', '', text)

doc = nlp(text)

print(list(doc.sents))
# Out:
# [PREOPERATIVE DIAGNOSES1  Right pelvic pain2  Right ovarian massPOSTOPERATIVE DIAGNOSES1  Right pelvic pain2  Right ovarian mass3  8 cm x 10 cm right ovarian cyst with ovarian torsionPROCEDURE PERFORMED  Laparoscopic right salpingooophorectomyANESTHESIA  General with endotracheal tubeCOMPLICATIONS  NoneESTIMATED BLOOD LOSS  Less than 50 ccTUBES  NoneDRAINS  NonePATHOLOGY  The right tube and ovary sent to pathology for reviewFINDINGS  On exam under anesthesia a normalappearing vulva and vagina and normally palpated cervix a uterus that was normal size and a large right adnexal mass  Laparoscopic findings demonstrated a 8 cm x 10 cm smooth right ovarian cyst that was noted to be torsed twice  Otherwise the uterus left tube and ovary bowel liver margins appendix and gallbladder were noted all to be within normal limits  There was no noted blood in the pelvisINDICATIONS FOR THIS PROCEDURE  The patient is a 26yearold G1 P1 who presented to ABCD General Emergency Room with complaint of right lower quadrant pain since last night which has been increasing in intensity  The pain persisted despite multiple pain medications given in the Emergency Room  The patient reports positive nausea and vomiting  There was no vaginal bleeding or discharge  There was no fevers or chills  Her cultures done in the Emergency Room were pending  The patient did have an ultrasound that demonstrated an 8 cm right ovarian cyst questionable hemorrhagic  The uterus and left ovary were within normal limits  There was a positive flow noted to bilateral ovaries on ultrasound  Therefore it was felt appropriate to take the patient for a diagnostic laparoscopy with a possible oophorectomyPROCEDURE  After informed consent was obtained and all questions were answered to the patients satisfaction in laymans terms she was taken to the operating room where general anesthesia was obtained without any difficulty  She was placed in dorsal lithotomy position with the use of Allis strips and prepped and draped in the usual sterile fashion  Her bladder was drained with a red Robinson catheter and she was examined under anesthesia and was noted to have the findings as above  She was prepped and draped in the usual sterile fashion  A weighted speculum was placed in the patients vagina with excellent visualization of the cervix  The cervix was grasped at 12 oclock position with a singletoothed tenaculum and pulled into the operative field  The uterus was then sounded to approximately 35 inches and then a uterine elevator was placed  The vulsellum tenaculum was removed  The weighted speculum was removed  Attention was then turned to the abdomen where 1 cm infraumbilical incision was made in the infraumbilical fold  The Veress step needle was then placed into the abdomen while the abdomen was being tented up with towel clamp  The CO2 was then turned on with unoccluded flow and excellent pressures  This was continued till a normal symmetrical pneumoperitoneum was obtained  Then a 11 mm step trocar and sleeve were placed into the infraumbilical port without any difficulty and placement was confirmed by laparoscope  Laparoscopic findings are as noted above  A suprapubic incision was made with the knife and then a 12 mm step trocar and sleeve were placed in the suprapubic region under direct visualization  Then a grasper was used to untorse the ovary  Then a 12 mm port was placed in the right flank region under direct visualization using a LigaSure vessel sealing system  The right tube and ovary were amputated and noted to be hemostatic  The EndoCatch bag was then placed through the suprapubic port and the ovary was placed into the bag  The ovary was too large to fit completely into the bag  Therefore a laparoscopic needle with a 60 cc syringe was used to aspirate the contents of the ovary while it was still inside the bagThere was approximately 200 cc of fluid aspirated from the cyst  This was a clear yellow fluid  Then the bag was closed and the ovary was removed from the suprapubic  ...

# %% [markdown]
# ## Find the Bio-Medical Entities in the given text:

# %%
print(doc.ents)
# Out:
# (pelvic pain, pelvic pain, right ovarian cyst, ovarian torsion, normalappearing vulva, vagina, adnexal mass  , right ovarian cyst, torsed, ovary bowel liver margins appendix and gallbladder, pain, pain, pain, nausea, vomiting, bleeding, chills, right ovarian cyst, singletoothed, CO2, LigaSure, 0vicyrl)

# %% [markdown]
# ### Abbreviations

# %% [markdown]
# The AbbreviationDetector is a Spacy component which implements the abbreviation detection algorithm in "A simple algorithm for identifying abbreviation definitions in biomedical text.", (Schwartz & Hearst, 2003).

# %%
nlp.add_pipe("abbreviation_detector")

# %%
doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

fmt_str = "{:<6}| {:<30}| {:<6}| {:<6}"
print(fmt_str.format("Short", "Long", "Starts", "Ends"))
for abrv in doc._.abbreviations:
    print(fmt_str.format(abrv.text, str(abrv._.long_form), abrv.start, abrv.end))
# Out:
# Short | Long                          | Starts| Ends
# SBMA  | Spinal and bulbar muscular atrophy| 6     | 7
# SBMA  | Spinal and bulbar muscular atrophy| 33    | 34
# AR    | androgen receptor             | 29    | 30

# %% [markdown]
# #### Finding Definitions

# %%
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# %% [markdown]
# The EntityLinker is a SpaCy component which performs linking to a knowledge base. The linker simply performs a string overlap - based search (char-3grams) on named entities, comparing them with the concepts in a knowledge base using an approximate nearest neighbours search.

# %% [markdown]
# scispaCy's EntityLinker class is a spaCy pipeline component that links entities identified by the trained pipeline with various clinical ontologies. In spaCy, these ontologies are called Knowledge Bases.
#
# As of writing, scispaCy supports the following: Unified Medical Language System, Medical Subject Headings, the RxNorm Ontology, the Gene Ontology, and the Human Phenotype Ontology.
#
# The EntityLinker uses an approximate nearest neighbors search to compare each identified entity to entries in the knowledge base.

# %%
linker = nlp.get_pipe("scispacy_linker")
doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

fmt_str = "{:<20}| {:<10}| {:<32}| {:<20}"
print(fmt_str.format("Entity", "1st CUI", "Canonical Name", "Definition"))
for entity in doc.ents:
    first_cuid = entity._.kb_ents[0][0]
    kb_entry = linker.kb.cui_to_entity[first_cuid]
    print(fmt_str.format(entity.text, first_cuid, kb_entry.canonical_name, kb_entry.definition[0:15] + "..."))
#https://www.andrewvillazon.com/clinical-natural-language-processing-python/
# Out:
# Entity              | 1st CUI   | Canonical Name                  | Definition
# Spinal and bulbar muscular atrophy| C1839259  | Bulbo-Spinal Atrophy, X-Linked  | An X-linked rec...
# SBMA                | C1705240  | AR wt Allele                    | Human AR wild-t...
# polyglutamine tract | C0032500  | Polyglutamic Acid               | A peptide that ...
# SBMA                | C1705240  | AR wt Allele                    | Human AR wild-t...

# %% [markdown]
# # Entity Detection

# %%
doc = nlp(text)

fmt_str = "{:<15}| {:<6}| {:<7}| {:<8}"
print(fmt_str.format("token", "pos", "label", "parent"))
for token in doc:
    print(fmt_str.format(token.text, token.pos_, token.ent_type_, token.head.text))
# Out:
# C:\Users\swanson-jeffrey\Anaconda3\envs\envname\lib\site-packages\scispacy\abbreviation.py:216: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   global_matches = self.global_matcher(doc)
# C:\Users\swanson-jeffrey\Anaconda3\envs\envname\lib\site-packages\scispacy\candidate_generation.py:284: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_neighbors[empty_vectors_boolean_flags] = numpy.array(neighbors)[:-1]
# C:\Users\swanson-jeffrey\Anaconda3\envs\envname\lib\site-packages\scispacy\candidate_generation.py:285: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   extended_distances[empty_vectors_boolean_flags] = numpy.array(distances)[:-1]
# token          | pos   | label  | parent
# PREOPERATIVE   | VERB  |        | noted
# DIAGNOSES1     | NOUN  |        | pain
#                | SPACE |        | pain
# Right          | ADJ   |        | pain
# pelvic         | ADJ   | DISEASE| pain
# pain           | NOUN  | DISEASE| POSTOPERATIVE
# 2              | NUM   |        |
#                | SPACE |        | POSTOPERATIVE
# Right          | ADJ   |        | ovarian
# ovarian        | ADJ   |        | mass
# mass           | NOUN  |        | POSTOPERATIVE
# POSTOPERATIVE  | NOUN  |        | PREOPERATIVE
# DIAGNOSES1     | NOUN  |        | POSTOPERATIVE
#                | SPACE |        | pain
# Right          | ADJ   |        | pain
# pelvic         | ADJ   | DISEASE| pain
# pain           | NOUN  | DISEASE| mass
# 2              | NUM   |        | mass
#                | SPACE |        | mass
# Right          | ADJ   |        | mass
# ovarian        | ADJ   |        | mass
# mass           | NOUN  |        | cyst
# 3              | NUM   |        |
#                | SPACE |        | cm
# 8              | NUM   |        | cm
# cm             | NOUN  |        | cyst
# x              | CCONJ |        | cm
# 10             | NUM   |        | cm
# cm             | NOUN  |        | cm
# right          | ADJ   | DISEASE| cyst
# ovarian        | ADJ   | DISEASE| cyst
# cyst           | NOUN  | DISEASE| PREOPERATIVE
# with           | ADP   |        | PROCEDURE
# ovarian        | ADJ   | DISEASE| PROCEDURE
# torsion        | NOUN  | DISEASE| PROCEDURE
# PROCEDURE      | NOUN  |        | PREOPERATIVE
# PERFORMED      | VERB  |        | PREOPERATIVE
#                | SPACE |        | salpingooophorectomy
# Laparoscopic   | ADJ   |        | salpingooophorectomy
# right          | ADJ   |        | salpingooophorectomy
# salpingooophorectomy| NOUN  |        | General
# ANESTHESIA     | PROPN |        | General
#                | SPACE |        | General
# General        | PROPN |        | PERFORMED
# with           | ADP   |        | COMPLICATIONS
# endotracheal   | NOUN  |        | tube
# tube           | NOUN  |        | COMPLICATIONS
# COMPLICATIONS  | NOUN  |        | PERFORMED
#                | SPACE |        | PREOPERATIVE
# None           | NOUN  |        | ESTIMATED
# ESTIMATED      | VERB  |        | BLOOD
# BLOOD          | PROPN |        | LOSS
# LOSS           | VERB  |        | PREOPERATIVE
#                | SPACE |        | TUBES
# Less           | ADJ   |        | 50
# than           | SCONJ |        | 50
# 50             | NUM   |        | TUBES
# cc             | NOUN  |        | TUBES
# TUBES          | PROPN |        |
#                | SPACE |        | LOSS
# None           | NOUN  |        |
# DRAINS         | VERB  |        |
#                | SPACE |        | LOSS
# None           | NOUN  |        | PATHOLOGY
# PATHOLOGY      | VERB  |        |
#                | SPACE |        | LOSS
# The            | DET   |        | tube
# right          | ADJ   |        | tube
# tube           | NOUN  |        |
# and            | CCONJ |        | tube
# ovary          | NOUN  |        | tube
# sent           | VERB  |        | LOSS
# to             | ADP   |        | pathology
# pathology      | NOUN  |        | sent
# for            | ADP   |        | FINDINGS
# review         | NOUN  |        | FINDINGS
# FINDINGS       | NOUN  |        | sent
#                | SPACE |        | FINDINGS
# On             | ADP   |        | exam
# exam           | NOUN  |        |
# under          | ADP   |        | anesthesia
# anesthesia     | NOUN  |        | exam
# a              | DET   |        | vulva
# normalappearing| ADJ   | DISEASE| vulva
# vulva          | NOUN  | DISEASE| FINDINGS
# and            | CCONJ |        | vulva
# vagina         | NOUN  | DISEASE| vulva
# and            | CCONJ |        | sent
# normally       | ADV   |        | palpated
# palpated       | VERB  |        | sent
# cervix         | NOUN  |        | palpated
# a              | DET   |        | uterus
# uterus         | NOUN  |        | palpated
# that           | DET   |        | size
# was            | VERB  |        | size
# normal         | ADJ   |        | size
# size           | NOUN  |        | uterus
# and            | CCONJ |        | size
# a              | DET   |        | findings
# large          | ADJ   |        | findings
# right          | ADJ   |        | findings
# adnexal        | ADJ   | DISEASE| findings
# mass           | NOUN  | DISEASE| findings
#                | SPACE | DISEASE| findings
# Laparoscopic   | ADJ   |        | findings
# findings       | NOUN  |        | demonstrated
# demonstrated   | VERB  |        | PREOPERATIVE
# a              | DET   |        | cyst
# 8              | NUM   |        | cm
# cm             | NOUN  |        | cyst
# x              | CCONJ |        | cm
# 10             | NUM   |        | cm
# cm             | NOUN  |        | cm
# smooth         | ADJ   |        | cyst
# right          | ADJ   | DISEASE| cyst
# ovarian        | ADJ   | DISEASE| cyst
# cyst           | NOUN  | DISEASE| demonstrated
# that           | DET   |        | noted
# was            | VERB  |        | noted
# noted          | VERB  |        | cyst
# to             | PART  |        | torsed
# be             | VERB  |        | torsed
# torsed         | VERB  | DISEASE| noted
# twice          | ADV   |        | torsed
#                | SPACE |        | left
# Otherwise      | ADV   |        | left
# the            | DET   |        | uterus
# uterus         | NOUN  |        | left
# left           | VERB  |        | PREOPERATIVE
# tube           | NOUN  |        | left
# and            | CCONJ |        | tube
# ovary          | ADJ   | DISEASE| bowel
# bowel          | NOUN  | DISEASE| appendix
# liver          | NOUN  | DISEASE| appendix
# margins        | NOUN  | DISEASE| appendix
# appendix       | NOUN  | DISEASE| tube
# and            | CCONJ | DISEASE| appendix
# gallbladder    | NOUN  | DISEASE| appendix
# were           | VERB  |        | noted
# noted          | VERB  |        | limits
# all            | DET   |        | noted
# to             | PART  |        | limits
# be             | VERB  |        | limits
# within         | ADP   |        | limits
# normal         | ADJ   |        | limits
# limits         | NOUN  |        | noted
#                | SPACE |        | noted
# There          | PRON  |        | was
# was            | VERB  |        | noted
# no             | DET   |        | blood
# noted          | VERB  |        | blood
# blood          | NOUN  |        | was
# in             | ADP   |        | pelvis
# the            | DET   |        | pelvis
# pelvis         | NOUN  |        | was
# INDICATIONS    | NOUN  |        | noted
# FOR            | ADP   |        | PROCEDURE
# THIS           | NOUN  |        | PROCEDURE
# PROCEDURE      | NOUN  |        | INDICATIONS
#                | SPACE |        | PROCEDURE
# The            | DET   |        | patient
# patient        | NOUN  |        | P1
# is             | VERB  |        | P1
# a              | DET   |        | P1
# 26yearold      | NOUN  |        | P1
# G1             | NOUN  |        | P1
# P1             | NOUN  |        | noted
# who            | PRON  |        | presented
# presented      | VERB  |        | P1
# to             | ADP   |        | Room
# ABCD           | PROPN |        | General
# General        | PROPN |        | Room
# Emergency      | PROPN |        | Room
# Room           | PROPN |        | presented
# with           | ADP   |        | complaint
# complaint      | NOUN  |        | presented
# of             | ADP   |        | pain
# right          | ADV   |        | lower
# lower          | ADJ   |        | pain
# quadrant       | ADJ   |        | pain
# pain           | NOUN  | DISEASE| complaint
# since          | SCONJ |        | night
# last           | ADJ   |        | night
# night          | NOUN  |        | presented
# which          | DET   |        | increasing
# has            | VERB  |        | increasing
# been           | VERB  |        | increasing
# increasing     | VERB  |        | P1
# in             | ADP   |        | intensity
# intensity      | NOUN  |        | increasing
#                | SPACE |        | noted
# The            | DET   |        | pain
# pain           | NOUN  | DISEASE| persisted
# persisted      | VERB  |        | noted
# despite        | SCONJ |        | medications
# multiple       | ADJ   |        | medications
# pain           | NOUN  | DISEASE| medications
# medications    | NOUN  |        | persisted
# given          | VERB  |        |
# in             | ADP   |        | Room
# the            | DET   |        | Room
# Emergency      | PROPN |        | Room
# Room           | PROPN |        |
#                | SPACE |        | medications
# The            | DET   |        | patient
# patient        | NOUN  |        | reports
# reports        | VERB  |        | medications
# positive       | ADJ   |        | nausea
# nausea         | NOUN  | DISEASE| reports
# and            | CCONJ |        | nausea
# vomiting       | NOUN  | DISEASE| nausea
#                | SPACE |        | vomiting
# There          | PRON  |        | was
# was            | VERB  |        | noted
# no             | DET   |        | bleeding
# vaginal        | ADJ   |        | bleeding
# bleeding       | NOUN  | DISEASE| was
# or             | CCONJ |        | bleeding
# discharge      | VERB  |        | bleeding
#                | SPACE |        | bleeding
# There          | PRON  |        | was
# was            | VERB  |        | noted
# no             | DET   |        | fevers
# fevers         | NOUN  |        | was
# or             | CCONJ |        | fevers
# chills         | NOUN  | DISEASE| fevers
#                | SPACE |        | fevers
# Her            | PRON  |        | cultures
# cultures       | NOUN  |        |
# done           | VERB  |        | cultures
# in             | ADP   |        | Room
# the            | DET   |        | Room
# Emergency      | PROPN |        | Room
# Room           | PROPN |        | done
# were           | VERB  |        | pending
# pending        | VERB  |        | was
#                | SPACE |        | pending
# The            | DET   |        | patient
# patient        | NOUN  |        | have
# did            | VERB  |        | have
# have           | VERB  |        | noted
# an             | DET   |        | ultrasound
# ultrasound     | NOUN  |        | have
# that           | DET   |        | demonstrated
# demonstrated   | VERB  |        | ultrasound
# an             | DET   |        | uterus
# 8              | NUM   |        | cm
# cm             | NOUN  |        | uterus
# right          | ADJ   | DISEASE| uterus
# ovarian        | ADJ   | DISEASE| cyst
# cyst           | NOUN  | DISEASE| uterus
# questionable   | ADJ   |        | uterus
# hemorrhagic    | ADJ   |        | uterus
#                | SPACE |        | uterus
# The            | DET   |        | uterus
# uterus         | NOUN  |        | demonstrated
# and            | CCONJ |        | demonstrated
# left           | VERB  |        | demonstrated
# ovary          | NOUN  |        | left
# were           | VERB  |        | limits
# within         | ADP   |        | limits
# normal         | ADJ   |        | limits
# limits         | NOUN  |        | drained
#                | SPACE |        | limits
# There          | PRON  |        | was
# was            | VERB  |        | limits
# a              | DET   |        | flow
# positive       | ADJ   |        | flow
# flow           | NOUN  |        | was
# noted          | VERB  |        | flow
# to             | PART  |        | ovaries
# bilateral      | ADJ   |        | ovaries
# ovaries        | NOUN  |        | noted
# on             | ADP   |        | ultrasound
# ultrasound     | NOUN  |        | ovaries
#                | SPACE |        | ovaries
# Therefore      | ADV   |        | felt
# it             | PRON  |        | felt
# was            | VERB  |        | felt
# felt           | VERB  |        | limits
# appropriate    | ADJ   |        | felt
# to             | PART  |        | take
# take           | VERB  |        | felt
# the            | DET   |        | patient
# patient        | NOUN  |        | take
# for            | ADP   |        | laparoscopy
# a              | DET   |        | laparoscopy
# diagnostic     | ADJ   |        | laparoscopy
# laparoscopy    | NOUN  |        | take
# with           | ADP   |        | PROCEDURE
# a              | DET   |        | PROCEDURE
# possible       | ADJ   |        | PROCEDURE
# oophorectomy   | NOUN  |        | PROCEDURE
# PROCEDURE      | NOUN  |        | laparoscopy
#                | SPACE |        | PROCEDURE
# After          | ADP   |        | consent
# informed       | ADJ   |        | consent
# consent        | NOUN  |        | obtained
# was            | VERB  |        | obtained
# obtained       | VERB  |        | limits
# and            | CCONJ |        | obtained
# all            | DET   |        | questions
# questions      | NOUN  |        | answered
# were           | VERB  |        | answered
# answered       | VERB  |        | obtained
# to             | PART  |        | satisfaction
# the            | DET   |        | satisfaction
# patients       | NOUN  |        | satisfaction
# satisfaction   | NOUN  |        | answered
# in             | ADP   |        | laymans
# laymans        | NOUN  |        | satisfaction
# terms          | NOUN  |        | answered
# she            | PRON  |        | taken
# was            | VERB  |        | taken
# taken          | VERB  |        | terms
# to             | ADP   |        | room
# the            | DET   |        | room
# operating      | NOUN  |        | room
# room           | NOUN  |        | taken
# where          | ADV   |        | obtained
# general        | ADJ   |        | anesthesia
# anesthesia     | NOUN  |        | obtained
# was            | VERB  |        | obtained
# obtained       | VERB  |        | room
# without        | ADP   |        | difficulty
# any            | DET   |        | difficulty
# difficulty     | NOUN  |        | obtained
#                | SPACE |        | difficulty
# She            | PRON  |        | placed
# was            | VERB  |        | placed
# placed         | VERB  |        | room
# in             | ADP   |        | position
# dorsal         | ADJ   |        | position
# lithotomy      | ADJ   |        | position
# position       | NOUN  |        | placed
# with           | ADP   |        | use
# the            | DET   |        | use
# use            | NOUN  |        | placed
# of             | ADP   |        | strips
# Allis          | PROPN |        | strips
# strips         | NOUN  |        | use
# and            | CCONJ |        | placed
# prepped        | VERB  |        | placed
# and            | CCONJ |        | prepped
# draped         | VERB  |        | prepped
# in             | ADP   |        | fashion
# the            | DET   |        | fashion
# usual          | ADJ   |        | fashion
# sterile        | ADJ   |        | fashion
# fashion        | NOUN  |        | draped
#                | SPACE |        | placed
# Her            | PRON  |        | bladder
# bladder        | NOUN  |        | drained
# was            | VERB  |        | drained
# drained        | VERB  |        | drained
# with           | ADP   |        | catheter
# a              | DET   |        | catheter
# red            | ADJ   |        | catheter
# Robinson       | PROPN |        | catheter
# catheter       | NOUN  |        | drained
# and            | CCONJ |        | drained
# she            | PRON  |        | examined
# was            | VERB  |        | examined
# examined       | VERB  |        | drained
# under          | ADP   |        | anesthesia
# anesthesia     | NOUN  |        | examined
# and            | CCONJ |        | examined
# was            | VERB  |        | noted
# noted          | VERB  |        | examined
# to             | PART  |        | have
# have           | VERB  |        | noted
# the            | DET   |        | findings
# findings       | NOUN  |        | have
# as             | ADP   |        |
# above          | ADP   |        | as
#                | SPACE |        | findings
# She            | PRON  |        | prepped
# was            | VERB  |        | prepped
# prepped        | VERB  |        | examined
# and            | CCONJ |        | prepped
# draped         | VERB  |        | prepped
# in             | ADP   |        | fashion
# the            | DET   |        | fashion
# usual          | ADJ   |        | fashion
# sterile        | ADJ   |        | fashion
# fashion        | NOUN  |        | draped
#                | SPACE |        | speculum
# A              | NOUN  |        | speculum
# weighted       | VERB  |        | speculum
# speculum       | NOUN  |        | placed
# was            | VERB  |        | placed
# placed         | VERB  |        | drained
# in             | ADP   |        | patients
# the            | DET   |        | patients
# patients       | NOUN  |        | placed
# vagina         | ADJ   |        | patients
# with           | ADP   |        | visualization
# excellent      | ADJ   |        | visualization
# visualization  | NOUN  |        | vagina
# of             | ADP   |        | cervix
# the            | DET   |        | cervix
# cervix         | NOUN  |        | visualization
#                | SPACE |        | cervix
# The            | DET   |        | cervix
# cervix         | NOUN  |        | grasped
# was            | VERB  |        | grasped
# grasped        | VERB  |        | drained
# at             | ADP   |        | position
# 12             | NUM   |        | position
# oclock         | NOUN  |        | position
# position       | NOUN  |        | grasped
# with           | ADP   |        | tenaculum
# a              | DET   |        | tenaculum
# singletoothed  | ADJ   | CHEMICAL| tenaculum
# tenaculum      | NOUN  |        | grasped
# and            | CCONJ |        | grasped
# pulled         | VERB  |        | grasped
# into           | ADP   |        | field
# the            | DET   |        | field
# operative      | ADJ   |        | field
# field          | NOUN  |        | pulled
#                | SPACE |        | sounded
# The            | DET   |        | uterus
# uterus         | NOUN  |        |
# was            | VERB  |        | sounded
# then           | ADV   |        | sounded
# sounded        | VERB  |        | grasped
# to             | PART  |        | inches
# approximately  | ADV   |        | 35
# 35             | NUM   |        | inches
# inches         | NOUN  |        | sounded
# and            | CCONJ |        | inches
# then           | ADV   |        | placed
# a              | DET   |        | elevator
# uterine        | ADJ   |        | elevator
# elevator       | NOUN  |        | placed
# was            | VERB  |        | placed
# placed         | VERB  |        | sounded
#                | SPACE |        | placed
# The            | DET   |        | tenaculum
# vulsellum      | NOUN  |        | tenaculum
# tenaculum      | NOUN  |        | removed
# was            | VERB  |        | removed
# removed        | VERB  |        | drained
#                | SPACE |        | removed
# The            | DET   |        | speculum
# weighted       | VERB  |        | speculum
# speculum       | NOUN  |        | removed
# was            | VERB  |        | removed
# removed        | VERB  |        | drained
#                | SPACE |        | Attention
# Attention      | NOUN  |        | turned
# was            | VERB  |        | turned
# then           | ADV   |        | turned
# turned         | VERB  |        | removed
# to             | ADP   |        | abdomen
# the            | DET   |        | abdomen
# abdomen        | NOUN  |        | turned
# where          | ADV   |        | made
# 1              | NUM   |        | cm
# cm             | NUM   |        | incision
# infraumbilical | NOUN  |        | incision
# incision       | NOUN  |        | made
# was            | VERB  |        | made
# made           | VERB  |        | abdomen
# in             | ADP   |        | infraumbilical
# the            | DET   |        | infraumbilical
# infraumbilical | NOUN  |        | made
# fold           | NOUN  |        | infraumbilical
#                | SPACE |        | abdomen
# The            | DET   |        | needle
# Veress         | NOUN  |        | needle
# step           | NOUN  |        | needle
# needle         | NOUN  |        | placed
# was            | VERB  |        | placed
# then           | ADV   |        | placed
# placed         | VERB  |        | turned
# into           | ADP   |        | abdomen
# the            | DET   |        | abdomen
# abdomen        | NOUN  |        | placed
# while          | SCONJ |        | tented
# the            | DET   |        | abdomen
# abdomen        | NOUN  |        | tented
# was            | VERB  |        | tented
# being          | VERB  |        | tented
# tented         | VERB  |        | placed
# up             | ADP   |        | tented
# with           | ADP   |        | clamp
# towel          | NOUN  |        | clamp
# clamp          | NOUN  |        | tented
#                | SPACE |        | clamp
# The            | DET   |        | CO2
# CO2            | NOUN  | CHEMICAL| turned
# was            | VERB  |        | turned
# then           | ADV   |        | turned
# turned         | VERB  |        | drained
# on             | ADP   |        | turned
# with           | ADP   |        | flow
# unoccluded     | ADJ   |        | flow
# flow           | NOUN  |        | turned
# and            | CCONJ |        | flow
# excellent      | ADJ   |        | pressures
# pressures      | NOUN  |        | flow
#                | SPACE |        | pressures
# This           | DET   |        |
# was            | VERB  |        | continued
# continued      | VERB  |        | turned
# till           | SCONJ |        | obtained
# a              | DET   |        | pneumoperitoneum
# normal         | ADJ   |        | pneumoperitoneum
# symmetrical    | ADJ   |        | pneumoperitoneum
# pneumoperitoneum| NOUN  |        | obtained
# was            | VERB  |        | obtained
# obtained       | VERB  |        | continued
#                | SPACE |        | obtained
# Then           | ADV   |        |
# a              | DET   |        | trocar
# 11             | NUM   |        | trocar
# mm             | NOUN  |        | trocar
# step           | NOUN  |        | trocar
# trocar         | NOUN  |        |
# and            | CCONJ |        | trocar
# sleeve         | NOUN  |        | trocar
# were           | VERB  |        | placed
# placed         | VERB  |        | turned
# into           | ADP   |        | port
# the            | DET   |        | port
# infraumbilical | ADJ   |        | port
# port           | NOUN  |        | placed
# without        | ADP   |        | difficulty
# any            | DET   |        | difficulty
# difficulty     | NOUN  |        | placed
# and            | CCONJ |        | difficulty
# placement      | NOUN  |        | difficulty
# was            | VERB  |        | confirmed
# confirmed      | VERB  |        | placed
# by             | ADP   |        | findings
# laparoscope    | NOUN  |        | findings
#                | SPACE |        | findings
# Laparoscopic   | ADJ   |        | findings
# findings       | NOUN  |        | noted
# are            | VERB  |        | noted
# as             | ADP   |        | noted
# noted          | VERB  |        | confirmed
# above          | ADP   |        | incision
#                | SPACE |        | incision
# A              | DET   |        | incision
# suprapubic     | ADJ   |        | incision
# incision       | NOUN  |        | made
# was            | VERB  |        | made
# made           | VERB  |        | noted
# with           | ADP   |        | knife
# the            | DET   |        | knife
# knife          | NOUN  |        | made
# and            | CCONJ |        | made
# then           | ADV   |        | trocar
# a              | DET   |        | trocar
# 12             | NUM   |        | mm
# mm             | NOUN  |        | trocar
# step           | NOUN  |        | trocar
# trocar         | NOUN  |        | made
# and            | CCONJ |        | trocar
# sleeve         | NOUN  |        | trocar
# were           | VERB  |        | placed
# placed         | VERB  |        | made
# in             | ADP   |        | region
# the            | DET   |        | region
# suprapubic     | ADJ   |        | region
# region         | NOUN  |        | placed
# under          | ADP   |        | visualization
# direct         | ADJ   |        | visualization
# visualization  | NOUN  |        | placed
#                | SPACE |        | visualization
# Then           | ADV   |        | used
# a              | DET   |        | grasper
# grasper        | NOUN  |        | used
# was            | VERB  |        | used
# used           | VERB  |        | noted
# to             | PART  |        | untorse
# untorse        | VERB  |        | used
# the            | DET   |        | ovary
# ovary          | NOUN  |        |
#                | SPACE |        | untorse
# Then           | ADV   |        | placed
# a              | DET   |        | port
# 12             | NUM   |        | mm
# mm             | NOUN  |        | port
# port           | NOUN  |        | placed
# was            | VERB  |        | placed
# placed         | VERB  |        | noted
# in             | ADP   |        | region
# the            | DET   |        | region
# right          | ADJ   |        | region
# flank          | ADJ   |        | region
# region         | NOUN  |        | placed
# under          | ADP   |        | visualization
# direct         | ADJ   |        | visualization
# visualization  | NOUN  |        | placed
# using          | VERB  |        | noted
# a              | DET   |        | system
# LigaSure       | NOUN  | CHEMICAL| vessel
# vessel         | NOUN  |        | system
# sealing        | NOUN  |        | system
# system         | NOUN  |        | using
#                | SPACE |        | system
# The            | DET   |        | tube
# right          | ADJ   |        | tube
# tube           | NOUN  |        |
# and            | CCONJ |        | tube
# ovary          | NOUN  |        | tube
# were           | VERB  |        | amputated
# amputated      | VERB  |        | drained
# and            | CCONJ |        | amputated
# noted          | VERB  |        | amputated
# to             | PART  |        | hemostatic
# be             | VERB  |        | hemostatic
# hemostatic     | ADJ   |        | bag
#                | SPACE |        | bag
# The            | DET   |        | bag
# EndoCatch      | PROPN |        | bag
# bag            | NOUN  |        | placed
# was            | VERB  |        | placed
# then           | ADV   |        | placed
# placed         | VERB  |        | noted
# through        | ADP   |        | port
# the            | DET   |        | port
# suprapubic     | ADJ   |        | port
# port           | NOUN  |        | placed
# and            | CCONJ |        | port
# the            | DET   |        | ovary
# ovary          | NOUN  |        | placed
# was            | VERB  |        | placed
# placed         | VERB  |        | placed
# into           | ADP   |        | bag
# the            | DET   |        | bag
# bag            | NOUN  |        | placed
#                | SPACE |        | bag
# The            | DET   |        | ovary
# ovary          | NOUN  |        |
# was            | VERB  |        | large
# too            | ADV   |        | large
# large          | ADJ   |        | drained
# to             | PART  |        | fit
# fit            | VERB  |        | large
# completely     | ADV   |        | fit
# into           | ADP   |        | bag
# the            | DET   |        | bag
# bag            | NOUN  |        | fit
#                | SPACE |        | fit
# Therefore      | ADV   |        | needle
# a              | DET   |        | needle
# laparoscopic   | ADJ   |        | needle
# needle         | NOUN  |        | large
# with           | ADP   |        | syringe
# a              | DET   |        | syringe
# 60             | NUM   |        | syringe
# cc             | NOUN  |        | syringe
# syringe        | NOUN  |        | needle
# was            | VERB  |        | used
# used           | VERB  |        | drained
# to             | PART  |        | aspirate
# aspirate       | VERB  |        | used
# the            | DET   |        | contents
# contents       | NOUN  |        | aspirate
# of             | ADP   |        | ovary
# the            | DET   |        | ovary
# ovary          | NOUN  |        | contents
# while          | SCONJ |        | was
# it             | PRON  |        | while
# was            | VERB  |        | while
# still          | ADV   |        | while
# inside         | ADP   |        | bag
# the            | DET   |        | bag
# bag            | NOUN  |        | while
# There          | PRON  |        | was
# was            | VERB  |        | drained
# approximately  | ADV   |        | 200
# 200            | NUM   |        | cc
# cc             | NOUN  |        | was
# of             | ADP   |        | fluid
# fluid          | NOUN  |        | cc
# aspirated      | VERB  |        | fluid
# from           | ADP   |        | cyst
# the            | DET   |        | cyst
# cyst           | NOUN  |        | aspirated
#                | SPACE |        | cyst
# This           | DET   |        | fluid
# was            | VERB  |        | fluid
# a              | DET   |        | fluid
# clear          | ADJ   |        | fluid
# yellow         | ADJ   |        | fluid
# fluid          | NOUN  |        | drained
#                | SPACE |        | fluid
# Then           | ADV   |        | closed
# the            | DET   |        | bag
# bag            | NOUN  |        | closed
# was            | VERB  |        | closed
# closed         | VERB  |        | drained
# and            | CCONJ |        | closed
# the            | DET   |        | ovary
# ovary          | NOUN  |        | removed
# was            | VERB  |        | removed
# removed        | VERB  |        | closed
# from           | ADP   |        | port
# the            | DET   |        | port
# suprapubic     | ADJ   |        | port
# port           | NOUN  |        | removed
#                | SPACE |        | port
# The            | DET   |        | port
# suprapubic     | ADJ   |        | port
# port           | NOUN  |        |
# did            | VERB  |        | have
# have           | VERB  |        | removed
# to             | PART  |        | extended
# be             | VERB  |        | extended
# extended       | VERB  |        | have
# somewhat       | ADV   |        | extended
# to             | PART  |        | allow
# allow          | VERB  |        | extended
# for            | ADP   |        | removal
# the            | DET   |        | removal
# removal        | NOUN  |        | allow
# of             | ADP   |        |
# the            | DET   |        |
# ovary          | NOUN  |        |
#                | SPACE |        | removal
# The            | DET   |        | trocar
# trocar         | NOUN  |        |
# and            | CCONJ |        | trocar
# sleeve         | NOUN  |        | trocar
# were           | VERB  |        | placed
# then           | ADV   |        | placed
# placed         | VERB  |        | allow
# back           | ADV   |        | placed
# into           | ADP   |        | port
# the            | DET   |        | port
# port           | NOUN  |        | placed
#                | SPACE |        | port
# The            | DET   |        | abdomen
# abdomen        | NOUN  |        |
# was            | VERB  |        | irrigated
# copiously      | ADV   |        | irrigated
# irrigated      | VERB  |        | placed
# with           | ADP   |        | saline
# warm           | ADJ   |        | saline
# normal         | ADJ   |        | saline
# saline         | NOUN  |        | irrigated
# using          | VERB  |        | placed
# the            | DET   |        | irrigator
# NezhatDorsey   | PROPN |        | irrigator
# suction        | NOUN  |        | irrigator
# irrigator      | NOUN  |        | using
# and            | CCONJ |        | irrigator
# the            | DET   |        | site
# incision       | NOUN  |        | site
# site           | NOUN  |        | irrigator
# was            | VERB  |        | noted
# noted          | VERB  |        | placed
# to             | PART  |        | hemostatic
# be             | VERB  |        | hemostatic
# hemostatic     | ADJ   |        | noted
#                | SPACE |        | pelvis
# The            | DET   |        | pelvis
# pelvis         | NOUN  |        | clear
# was            | VERB  |        | clear
# clear          | ADJ   |        | hemostatic
# and            | CCONJ |        | clear
# clean          | ADJ   |        | clear
#                | SPACE |        | Pictures
# Pictures       | PROPN |        | obtained
# were           | VERB  |        | obtained
# obtained       | VERB  |        | drained
#                | SPACE |        | obtained
# The            | DET   |        | port
# suprapubic     | ADJ   |        | port
# port           | NOUN  |        | removed
# was            | VERB  |        | removed
# then           | ADV   |        | removed
# removed        | VERB  |        | obtained
# under          | ADP   |        | visualization
# direct         | ADJ   |        | visualization
# visualization  | NOUN  |        | removed
# and            | CCONJ |        | removed
# then           | ADV   |        | using
# using          | VERB  |        | removed
# a              | DET   |        | 0vicyrl
# 0vicyrl        | NOUN  | CHEMICAL| using
# and            | CCONJ |        | 0vicyrl
# UR6            | NOUN  |        | 0vicyrl
#                | SPACE |        | sutures
# Two            | NUM   |        | sutures
# figureofeight  | NOUN  |        | sutures
# sutures        | NOUN  |        | placed
# were           | VERB  |        | placed
# placed         | VERB  |        | removed
# in             | ADP   |        | fascia
# the            | DET   |        | fascia
# fascia         | NOUN  |        | placed
# of             | ADP   |        | port
# suprapubic     | ADJ   |        | port
# port           | NOUN  |        | fascia
# and            | CCONJ |        | port
# fascia         | NOUN  |        | port
# was            | VERB  |        | closed
# closed         | VERB  |        | drained
# and            | CCONJ |        | closed
# the            | DET   |        | pneumoperitoneum
# pneumoperitoneum| NOUN  |        | maintained
# was            | VERB  |        | maintained
# maintained     | VERB  |        | closed
# after          | ADP   |        | placed
# the            | DET   |        | sutures
# sutures        | NOUN  |        | placed
# were           | VERB  |        | placed
# placed         | VERB  |        | maintained
#                | SPACE |        | placed
# Therefore      | ADV   |        | noted
# the            | DET   |        | surface
# peritoneal     | ADJ   |        | surface
# surface        | NOUN  |        | noted
# was            | VERB  |        | noted
# noted          | VERB  |        | drained
# to             | PART  |        | hemostatic
# be             | VERB  |        | hemostatic
# hemostatic     | ADJ   |        | noted
#                | SPACE |        | hemostatic
# Therefore      | ADV   |        | removed
# the            | DET   |        | camera
# camera         | NOUN  |        | removed
# was            | VERB  |        | removed
# removed        | VERB  |        | drained
#                | SPACE |        | removed
# All            | DET   |        | instruments
# instruments    | NOUN  |        | removed
# were           | VERB  |        | removed
# removed        | VERB  |        |
#                | SPACE |        | removed
# The            | DET   |        | abdomen
# abdomen        | NOUN  |        | allowed
# was            | VERB  |        | allowed
# allowed        | VERB  |        | removed
# to             | PART  |        | deflate
# completely     | ADV   |        | deflate
# deflate        | VERB  |        | allowed
# and            | CCONJ |        | deflate
# then           | ADV   |        | placed
# the            | DET   |        | trocars
# trocars        | NOUN  |        | placed
# were           | VERB  |        | placed
# placed         | VERB  |        | deflate
# back           | ADV   |        | placed
# through        | ADP   |        | sleeves
# the            | DET   |        | sleeves
# sleeves        | NOUN  |        | placed
# of             | ADP   |        | port
# the            | DET   |        | port
# right          | ADJ   |        | flank
# flank          | NOUN  |        | port
# 12             | NUM   |        | port
# port           | NOUN  |        | sleeves
# and            | CCONJ |        | port
# the            | DET   |        | port
# infraumbilical | ADJ   |        | port
# port           | NOUN  |        | port
# and            | CCONJ |        | placed
# these          | DET   |        | removed
# were           | VERB  |        | removed
# removed        | VERB  |        | placed
#                | SPACE |        | removed
# The            | DET   |        | port
# infraumbilical | ADJ   |        | port
# port           | NOUN  |        | examined
# was            | VERB  |        | examined
# examined       | VERB  |        | drained
# and            | CCONJ |        | examined
# noted          | VERB  |        | examined
# to             | PART  |        | have
# have           | VERB  |        | noted
# a              | DET   |        | defect
# small          | ADJ   |        | defect
# fascial        | ADJ   |        | defect
# defect         | NOUN  |        | have
# which          | DET   |        | repaired
# was            | VERB  |        | repaired
# repaired       | VERB  |        | defect
# with           | ADP   |        | 0Vicryl
# 0Vicryl        | NOUN  |        | repaired
# and            | CCONJ |        | 0Vicryl
# UR6            | NOUN  |        | 0Vicryl
#                | SPACE |        | drained
# The            | DET   |        | area
# right          | ADJ   |        | area
# flank          | NOUN  |        | area
# area           | NOUN  |        | palpated
# was            | VERB  |        | palpated
# palpated       | VERB  |        | drained
# and            | CCONJ |        | palpated
# there          | PRON  |        | was
# was            | VERB  |        | palpated
# no             | DET   |        | defect
# facial         | ADJ   |        | defect
# defect         | NOUN  |        | was
# noted          | VERB  |        | defect
#                | SPACE |        | noted
# The            | DET   |        | skin
# skin           | NOUN  |        | closed
# was            | VERB  |        | closed
# then           | ADV   |        | closed
# closed         | VERB  |        | noted
# with           | ADP   |        | Vicryl
# 40             | NUM   |        | Vicryl
# undyed         | VERB  |        | Vicryl
# Vicryl         | PROPN |        | closed
# in             | ADP   |        | fashion
# subcuticular   | ADJ   |        | fashion
# fashion        | NOUN  |        | closed
#                | SPACE |        | Dressings
# Dressings      | NOUN  |        | changed
# were           | VERB  |        | changed
# changed        | VERB  |        | closed
#                | SPACE |        | changed
# The            | DET   |        | speculum
# weighted       | VERB  |        | speculum
# speculum       | NOUN  |        | removed
# was            | VERB  |        | removed
# removed        | VERB  |        | palpated
# from           | ADP   |        | cervix
# the            | DET   |        | cervix
# patients       | NOUN  |        | cervix
# cervix         | NOUN  |        | removed
#                | SPACE |        | cervix
# The            | DET   |        | cervix
# cervix         | NOUN  |        | cervix
# noted          | VERB  |        | drained
# to             | PART  |        | hemostatic
# be             | VERB  |        | hemostatic
# hemostatic     | ADJ   |        | patient
#                | SPACE |        | patient
# The            | DET   |        | patient
# patient        | NOUN  |        | tolerated
# tolerated      | VERB  |        | noted
# the            | DET   |        | procedure
# procedure      | NOUN  |        | tolerated
# well           | ADV   |        | procedure
#                | SPACE |        | counts
# Sponge         | PROPN |        | lap
# lap            | NOUN  |        | counts
# and            | CCONJ |        | lap
# needle         | NOUN  |        | lap
# counts         | NOUN  |        | correct
# were           | VERB  |        | correct
# correct        | ADJ   |        | drained
# x2             | ADJ   |        | correct
# and            | CCONJ |        | correct
# the            | DET   |        | patient
# patient        | NOUN  |        | taken
# was            | VERB  |        | taken
# taken          | VERB  |        | correct
# to             | ADP   |        | Recovery
# the            | DET   |        | Recovery
# Recovery       | PROPN |        | taken
# in             | ADP   |        | condition
# stable         | ADJ   |        | condition
# condition      | NOUN  |        | taken

# %% [markdown]
# # Named Entity Recognition

# %% [markdown]
# Named entity recognition (NER) is a task where the model has to find which parts of the input text correspond to entities such as persons, locations, or organizations. It involves the identification of key information in the text and classification into a set of predefined categories. An entity is basically the thing that is consistently talked about or refer to in the text.

# %%
import pandas as pd
import re
med_transcript = pd.read_csv(r"C:\Users\swanson-jeffrey\Downloads\mtsamples.csv", index_col=0)
med_transcript.dropna(subset=['transcription'], inplace=True)
med_transcript_small = med_transcript.sample(n=100, replace=False, random_state=42)


sample_transcription = med_transcript_small['transcription'].iloc[0]
sample_transcription=re.sub(r'[^\w\s]', '', sample_transcription)
print(sample_transcription[:1000]) # prints just the first 1000 characters
# Out:
# HISTORY OF PRESENT ILLNESS  The patient is well known to me for a history of irondeficiency anemia due to chronic blood loss from colitis  We corrected her hematocrit last year with intravenous IV iron  Ultimately she had a total proctocolectomy done on 03142007 to treat her colitis  Her course has been very complicated since then with needing multiple surgeries for removal of hematoma  This is partly because she was on anticoagulation for a right arm deep venous thrombosis DVT she had early this year complicated by septic phlebitisChart was reviewed and I will not reiterate her complex historyI am asked to see the patient again because of concerns for coagulopathyShe had surgery again last month to evacuate a pelvic hematoma and was found to have vancomycin resistant enterococcus for which she is on multiple antibiotics and followed by infectious disease nowShe is on total parenteral nutrition TPN as wellLABORATORY DATA  Labs today showed a white blood count of 79 hemoglobin 110 hemat

# %%
#https://allenai.github.io/scispacy/
import scispacy

import spacy
#pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_lg-0.4.0.tar.gz
nlp = spacy.load("en_ner_bc5cdr_md")
doc = nlp(sample_transcription)
print("TEXT", "START", "END", "ENTITY TYPE")
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# TEXT START END ENTITY TYPE
# irondeficiency anemia 77 98 DISEASE
# chronic blood loss 106 124 DISEASE
# colitis 130 137 DISEASE
# iron 197 201 CHEMICAL
# colitis 276 283 DISEASE
# hematoma 380 388 DISEASE
# venous thrombosis DVT 461 482 DISEASE
# pelvic hematoma 720 735 DISEASE
# vancomycin 758 768 CHEMICAL
# infectious disease 849 867 DISEASE
# wellLABORATORY 915 929 CHEMICAL
# improvedPT 1299 1309 CHEMICAL
# vitamin K 1446 1455 CHEMICAL
# 28LFTs 1659 1665 CHEMICAL
# uric acid 1755 1764 CHEMICAL
# bilirubin 1776 1785 CHEMICAL
# Creatinine 1830 1840 CHEMICAL
# creatinine 1868 1878 CHEMICAL
# normalB12 1931 1940 CHEMICAL
# Folic acid 1989 1999 CHEMICAL
# Iron 2012 2016 CHEMICAL
# heparin 2220 2227 CHEMICAL
# loperamide niacin 2236 2253 CHEMICAL
# Diovan Afrin 2267 2279 CHEMICAL
# caspofungin daptomycin 2292 2314 CHEMICAL
# fentanyl 2325 2333 CHEMICAL
# morphine 2337 2345 CHEMICAL
# pain 2350 2354 DISEASE
# Compazine 2359 2368 CHEMICAL
# Zofran 2372 2378 CHEMICAL
# epistaxis 2504 2513 DISEASE
# notedABDOMEN 2754 2766 CHEMICAL
# bleeding 2910 2918 DISEASE
# adenopathy 3000 3010 DISEASE
# vitamin K 3132 3141 CHEMICAL
# prealbuminIt 3294 3306 CHEMICAL
# lupus 3540 3545 DISEASE
# bleeding 3595 3603 DISEASE
# infection 3768 3777 DISEASE
# myeloproliferative disorderAnemia 3797 3830 DISEASE
# creatinine 3890 3900 CHEMICAL
# iron 3956 3960 CHEMICAL
# iron 4048 4052 CHEMICAL
# small bowel 4094 4105 DISEASE
# iron 4180 4184 CHEMICAL
# inflammation 4324 4336 DISEASE
# iron 4377 4381 CHEMICAL
# iron 4486 4490 CHEMICAL

# %% [markdown]
# We are going to use the NER model trained on the BC5CDR corpus (en_ner_bc5cdr_md). This corpus consists of 1500 PubMed articles with 4409 annotated chemicals, 5818 diseases, and 3116 chemical-disease interactions.

# %%
from spacy import displacy
displacy.render(doc[:200], style='ent', jupyter=True) # here I am printing just the first 100 tokens
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">HISTORY OF PRESENT ILLNESS  The patient is well known to me for a history of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     irondeficiency anemia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  due to
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chronic blood loss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  from
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     colitis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#   We corrected her hematocrit last year with intravenous IV
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#   Ultimately she had a total proctocolectomy done on 03142007 to treat her
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     colitis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#   Her course has been very complicated since then with needing multiple surgeries for removal of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hematoma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#   This is partly because she was on anticoagulation for a right arm deep
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     venous thrombosis DVT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  she had early this year complicated by septic phlebitisChart was reviewed and I will not reiterate her complex historyI am asked to see the patient again because of concerns for coagulopathyShe had surgery again last month to evacuate a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pelvic hematoma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  and was found to have
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vancomycin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  resistant enterococcus for which she is on multiple antibiotics and followed by
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     infectious disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  nowShe is on total parenteral nutrition TPN as
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     wellLABORATORY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  DATA  Labs today showed a white blood count of 79 hemoglobin 110 hematocrit 328 and platelets 1121000  MCV is 89  Her platelets have been elevated for at least the past week with counts initially at the 600000 to 700000 range and in the </div></span>

# %% [markdown]
# Named entity recognition (NER) ‒ also called entity identification or entity extraction ‒ is a natural language processing (NLP) technique that automatically identifies named entities in a text and classifies them into predefined categories. Entities can be names of people, organizations, locations, times, quantities, monetary values, percentages, and more.

# %% [markdown]
# ## Rule-based matching

# %% [markdown]
# Rule-based matching is similar to regular expressions, but spaCy’s rule-based matcher engines and components give you access to the tokens within the document and their relationships. We can combine this with the NER models to identify some pattern that includes our entities.
#
# Let’s extract from the text the drug names and their reported dosages. This could be of real use to identify possible medication errors by checking if the dosages are in accordance with standards and guidelines.

# %%
from spacy.matcher import Matcher

pattern = [{'ENT_TYPE':'CHEMICAL'}, {'LIKE_NUM': True}, {'IS_ASCII': True}]
matcher = Matcher(nlp.vocab)
matcher.add("DRUG_DOSE", [pattern])

# %% [markdown]
# The code above creates a pattern to identify a sequence of three tokens:
#
# A token whose entity type is CHEMICAL (drug name)
# A token that resembles a number (dosage)
# A token that consists of ASCII characters (units, like mg or mL)
# Then we initialize the Matcher with a vocabulary. The matcher must always share the same vocab with the documents it will operate on, so we use the nlp object vocab. We then add this pattern to the matcher and give it an ID.
#
# Now we can loop through all transcriptions and extract the text matching this pattern:

# %%
for transcription in med_transcript_small['transcription']:
    doc = nlp(transcription)
    matches = matcher(doc)
    for match_id, start, end in matches:
        string_id = nlp.vocab.strings[match_id]  # get string representation
        span = doc[start:end]  # the matched span
        print(string_id, start, end, span.text)
# Out:
# DRUG_DOSE 129 132 Xylocaine 20 mL
# DRUG_DOSE 133 136 Marcaine 0.25%
# DRUG_DOSE 204 207 Aspirin 81 mg
# DRUG_DOSE 212 215 Spiriva 10 mcg
# DRUG_DOSE 376 379 nifedipine 10 mg
# DRUG_DOSE 220 223 aspirin one tablet
# DRUG_DOSE 239 242 Warfarin 2.5 mg
# DRUG_DOSE 57 60 Topamax 100 mg
# DRUG_DOSE 63 66 Zoloft 100 mg
# DRUG_DOSE 69 72 Abilify 5 mg
# DRUG_DOSE 74 77 Motrin 800 mg
# DRUG_DOSE 76 79 Xanax 1 mg
# DRUG_DOSE 87 90 Colace 100 mg
# DRUG_DOSE 120 123 Paxil 10 mg
# DRUG_DOSE 125 128 Prednisone 20 mg
# DRUG_DOSE 139 142 Metamucil one pack
# DRUG_DOSE 149 152 Nexium 40 mg
# DRUG_DOSE 89 92 (70-
# DRUG_DOSE 91 94 -86)
# DRUG_DOSE 1109 1112 Naprosyn one p.o
# DRUG_DOSE 260 263 Lidocaine 1%
# DRUG_DOSE 35 38 Altrua 60,
# DRUG_DOSE 221 224 lidocaine 2%
# DRUG_DOSE 91 94 Creatinine 1.3,
# DRUG_DOSE 94 97 sodium 141,
# DRUG_DOSE 98 101 potassium 4.0.
# DRUG_DOSE 102 105 Calcium 8.6.
# DRUG_DOSE 434 437 aspirin 81 mg
# DRUG_DOSE 441 444 Lipitor 20 mg
# DRUG_DOSE 448 451 Klonopin 0.5 mg
# DRUG_DOSE 456 459 digoxin 0.125 mg
# DRUG_DOSE 463 466 Lexapro 10 mg
# DRUG_DOSE 478 481 Lasix 20 mg
# DRUG_DOSE 497 500 Prinivil 40 mg
# DRUG_DOSE 504 507 Lopressor 75 mg
# DRUG_DOSE 512 515 Starlix 120 mg
# DRUG_DOSE 529 532 glycol 17 g
# DRUG_DOSE 539 542 chloride 20 mEq
# DRUG_DOSE 557 560 Zofran 4 mg
# DRUG_DOSE 944 947 Lexapro 10 mg
# DRUG_DOSE 312 315 Premarin 1.25 mg
# DRUG_DOSE 317 320 Elmiron 100 mg
# DRUG_DOSE 323 326 Elavil 50 mg
# DRUG_DOSE 329 332 OxyContin 10 mg
# DRUG_DOSE 66 69 Lidocaine 1.5%
# DRUG_DOSE 205 208 Dilantin 300 mg
# DRUG_DOSE 211 214 Haloperidol 1 mg
# DRUG_DOSE 217 220 Dexamethasone 4 mg
# DRUG_DOSE 226 229 Docusate 100 mg
# DRUG_DOSE 238 241 Ibuprofen 600 mg
# DRUG_DOSE 244 247 Zantac 150 mg
# DRUG_DOSE 252 255 Temodar 100 mg
# DRUG_DOSE 327 330 Klonopin 1 mg
# DRUG_DOSE 336 339 lithium 450 mg
# DRUG_DOSE 342 345 Depakote 1000 mg
# DRUG_DOSE 348 351 Seroquel 1000 mg
# DRUG_DOSE 1097 1100 omeprazole 20 mg
# DRUG_DOSE 182 185 Xylocaine 1%
# DRUG_DOSE 187 190 epinephrine 7 ml
# DRUG_DOSE 201 204 Percocet 5,
# DRUG_DOSE 2356 2359 Naprosyn 375 mg
# DRUG_DOSE 141 144 Wellbutrin 300 mg
# DRUG_DOSE 146 149 Xanax 0.25 mg
# DRUG_DOSE 158 161 omeprazole 20 mg
# DRUG_DOSE 324 327 iron 240 mg
# DRUG_DOSE 330 333 Paxil 20 mg
# DRUG_DOSE 356 359 warfarin 1 mg
# DRUG_DOSE 377 380 Neurontin 300 mg
# DRUG_DOSE 855 858 Imuran 100 mg
# DRUG_DOSE 988 991 Zantac 150 mg
# DRUG_DOSE 732 735 Vicodin 1-
# DRUG_DOSE 268 271 morphine 1 mg
# DRUG_DOSE 272 275 Versed 2 mg
# DRUG_DOSE 120 123 Keppra 1500 twice
# DRUG_DOSE 126 129 Decadron 6 mg
# DRUG_DOSE 148 151 Dilantin 300 a
# DRUG_DOSE 222 225 Losartan 50 mg
# DRUG_DOSE 228 231 Nifedipine 90 mg
# DRUG_DOSE 435 438 creatinine 8.7,
# DRUG_DOSE 438 441 potassium 7.3,
# DRUG_DOSE 465 468 Lortab 7.5 to
# DRUG_DOSE 293 296 lidocaine 2%
# DRUG_DOSE 304 307 Marcaine 0.5%
# DRUG_DOSE 24 27 Versed 5 mg
# DRUG_DOSE 302 305 Nexium 40 mg

# %% [markdown]
# # Additional Techniques

# %% [markdown]
# The Hugging Face Transformers provides thousands of pre-trained models to perform tasks on texts such as classification, information extraction, question answering, summarization, translation, text generation, and more in over 100 languages. Its aim is to make cutting-edge NLP easier to use for everyone. The Model Hub contains thousands of pre-trained models that anyone can download and use. It also contains a large number of datasets for NLP projects. https://huggingface.co/

# %% [markdown]
# - fill-mask: Masked Language Modeling is a fill-in-the-blank task, where a model uses the context words surrounding a mask token to try to predict what the masked word should be. For an input that contains one or more mask tokens, the model will generate the most likely substitution for each.
#     - Input: "I have watched this [MASK] and it was awesome."
#     - Output: "I have watched this movie and it was awesome."
# - question-answering: Question answering is a task in information retrieval and Natural Language Processing (NLP) that investigates software that can answer questions asked by humans in natural language. In Extractive Question Answering, a context is provided so that the model can refer to it and make predictions on where the answer lies within the passage.
# - sentiment-analysis seeks to identify the writer’s (or speaker’s) mood, opinion, or feelings towards the topic.
# - summarization: Text summarization is the practice of breaking down long publications into manageable paragraphs or sentences. The procedure extracts important information while also ensuring that the paragraph's sense is preserved. This shortens the time it takes to comprehend long materials like research articles while without omitting critical information.
# - text-generation :It leverages knowledge in computational linguistics and artificial intelligence to automatically generate natural language texts, which can satisfy certain communicative requirements.
# - translation: a procedure when a computer software translates text from one language to another without human contribution
# - zero-shot-classification: capable of describing what class an unlabeled sample belongs to when it does not fall into the category of any of the trained categories. i.e. Zero shots for the datapoint.
